# %%
import os
import math
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import timeit
from datetime import datetime

# %%
# First method using tf.function() [eager vs graph]
x = tf.random.uniform(shape=[10,10],minval = -1,maxval = 2,dtype = tf.dtypes.int32)

def power(x,y):
  result = tf.eye(10,dtype=tf.dtypes.int32)
  for _ in range(y):
    result = tf.matmul(x,result)
  return result

# %%
print("Eager Execution: ",timeit.timeit(lambda : power(x,100),number = 1000),"seconds")
# Out:
# Eager Execution:  5.028842370999996 seconds

# %%
power_graph = tf.function(power)
print("Graph execution: ",timeit.timeit(lambda : power_graph(x,100),number=1000),"seconds")
# Out:
# Graph execution:  0.9904186790000153 seconds

# %%
# Second method using decorator
@tf.function
def add_num(a,b):
  return tf.add(a,b,name='sum')

a=tf.constant(5,name='a')
b=tf.constant(7,name='b')

result = add_num(a,b)
print("Result: ",result.numpy())
print("Graph execution: ",timeit.timeit(lambda : add_num(a,b),number=1000),"seconds")
# Out:
# Result:  12
# Graph execution:  0.510528254999997 seconds

# %%
from keras.layers import Dense, Conv2D, BatchNormalization
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers import Input, Flatten,Dropout
from keras.layers import concatenate, Activation
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import LearningRateScheduler
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.utils import plot_model, to_categorical

# %%
#Image Classification using DenseNet

cifar10 = keras.datasets.cifar10
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 12s 0us/step

# %%
batch_size = 64
epochs = 8
data_augmentation = True

num_classes = 10
num_dense_blocks = 3
use_max_pool = False

# %%
growth_rate = 12
depth = 100
num_bottleneck_layers = (depth - 4) // (2*num_dense_blocks)

num_filters_dense_blocks = 2*growth_rate
compression_factor = 0.5

# %%
input_shape = x_train.shape[1:]

x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

y_train = to_categorical(y_train,num_classes)
y_test = to_categorical(y_test,num_classes)

# %%
def lr_schedule(epoch):
  lr = 1e-3
  if epoch > 180:
    lr *= 0.5e-3
  elif epoch > 160:
    lr *= 1e-3
  elif epoch > 120:
    lr *= 1e-2
  elif epoch > 80:
    lr *= 1e-1
  print("Learning Rate: ",lr)
  return lr

# %%
inputs = Input(shape = input_shape)
x = BatchNormalization()(inputs)
x = Activation('relu')(x)
x = Conv2D(num_filters_dense_blocks,kernel_size = 3,padding = 'same',kernel_initializer='he_normal')(x)
x = concatenate([inputs,x])

# %%
for i in range(num_dense_blocks):
  for j in range(num_bottleneck_layers):
    y = BatchNormalization()(x)
    y = Activation('relu')(y)
    y = Conv2D(4*growth_rate,kernel_size=1,padding='same',kernel_initializer='he_normal')(y)

    if not data_augmentation:
      y = Dropout(0.2)(y)
      y = BatchNormalization()(y)
      y = Activation('relu')(y)
      y = Conv2D(growth_rate,kernel_size=3,padding='same',kernel_initializer='he_normal')(y)
    if not data_augmentation:
      y = Dropout(0.2)(y)
    x = concatenate([x,y])

  # no transition layer after last dense block
  if i == num_dense_blocks - 1:
    continue

  # transition layer compresses num of feature maps & reduces size by 2
  num_filters_dense_blocks += num_bottleneck_layers * growth_rate
  num_filters_dense_blocks = int(num_filters_dense_blocks * compression_factor)
  y = BatchNormalization()(x)
  y = Conv2D(num_filters_dense_blocks,kernel_size=1,padding='same',kernel_initializer='he_normal')(y)
  if not data_augmentation:
    y = Dropout(0.2)(y)
  x = AveragePooling2D()(y)

# %%
x = AveragePooling2D(pool_size=8)(x)
y = Flatten()(x)

outputs = Dense(num_classes, kernel_initializer='he_normal', activation='softmax')(y)

# %%
model = Model(inputs=inputs,outputs=outputs)

model.compile(loss='categorical_crossentropy',
              optimizer = RMSprop(1e-3),
              metrics = ['acc'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  batch_normalization (Batch  (None, 32, 32, 3)            12        ['input_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 3)            0         ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 24)           672       ['activation[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 27)           0         ['input_1[0][0]',
#                                                                      'conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 27)           108       ['concatenate[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 27)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 48)           1344      ['activation_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 75)           0         ['concatenate[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 75)           300       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 75)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 48)           3648      ['activation_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 123)          0         ['concatenate_1[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 123)          492       ['concatenate_2[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 123)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 48)           5952      ['activation_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 171)          0         ['concatenate_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 171)          684       ['concatenate_3[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 171)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 48)           8256      ['activation_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 32, 32, 219)          0         ['concatenate_3[0][0]',
#  )                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 219)          876       ['concatenate_4[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 219)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 48)           10560     ['activation_5[0][0]']
#
#  concatenate_5 (Concatenate  (None, 32, 32, 267)          0         ['concatenate_4[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 267)          1068      ['concatenate_5[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 267)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 48)           12864     ['activation_6[0][0]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 315)          0         ['concatenate_5[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 315)          1260      ['concatenate_6[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 315)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 48)           15168     ['activation_7[0][0]']
#
#  concatenate_7 (Concatenate  (None, 32, 32, 363)          0         ['concatenate_6[0][0]',
#  )                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 363)          1452      ['concatenate_7[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 363)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 48)           17472     ['activation_8[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 411)          0         ['concatenate_7[0][0]',
#  )                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 411)          1644      ['concatenate_8[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 411)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 48)           19776     ['activation_9[0][0]']
#
#  concatenate_9 (Concatenate  (None, 32, 32, 459)          0         ['concatenate_8[0][0]',
#  )                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 459)          1836      ['concatenate_9[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 459)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 48)           22080     ['activation_10[0][0]']
#
#  concatenate_10 (Concatenat  (None, 32, 32, 507)          0         ['concatenate_9[0][0]',
#  e)                                                                  'conv2d_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 507)          2028      ['concatenate_10[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 507)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 48)           24384     ['activation_11[0][0]']
#
#  concatenate_11 (Concatenat  (None, 32, 32, 555)          0         ['concatenate_10[0][0]',
#  e)                                                                  'conv2d_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 555)          2220      ['concatenate_11[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 555)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 48)           26688     ['activation_12[0][0]']
#
#  concatenate_12 (Concatenat  (None, 32, 32, 603)          0         ['concatenate_11[0][0]',
#  e)                                                                  'conv2d_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 603)          2412      ['concatenate_12[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 603)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 48)           28992     ['activation_13[0][0]']
#
#  concatenate_13 (Concatenat  (None, 32, 32, 651)          0         ['concatenate_12[0][0]',
#  e)                                                                  'conv2d_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 651)          2604      ['concatenate_13[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 651)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 48)           31296     ['activation_14[0][0]']
#
#  concatenate_14 (Concatenat  (None, 32, 32, 699)          0         ['concatenate_13[0][0]',
#  e)                                                                  'conv2d_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 699)          2796      ['concatenate_14[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 699)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 48)           33600     ['activation_15[0][0]']
#
#  concatenate_15 (Concatenat  (None, 32, 32, 747)          0         ['concatenate_14[0][0]',
#  e)                                                                  'conv2d_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 747)          2988      ['concatenate_15[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 747)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 48)           35904     ['activation_16[0][0]']
#
#  concatenate_16 (Concatenat  (None, 32, 32, 795)          0         ['concatenate_15[0][0]',
#  e)                                                                  'conv2d_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 795)          3180      ['concatenate_16[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 108)          85968     ['batch_normalization_17[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 16, 16, 108)          0         ['conv2d_17[0][0]']
#  Pooling2D)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 108)          432       ['average_pooling2d[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 108)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 48)           5232      ['activation_17[0][0]']
#
#  concatenate_17 (Concatenat  (None, 16, 16, 156)          0         ['average_pooling2d[0][0]',
#  e)                                                                  'conv2d_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 16, 16, 156)          624       ['concatenate_17[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 156)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 48)           7536      ['activation_18[0][0]']
#
#  concatenate_18 (Concatenat  (None, 16, 16, 204)          0         ['concatenate_17[0][0]',
#  e)                                                                  'conv2d_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 16, 16, 204)          816       ['concatenate_18[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 204)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 48)           9840      ['activation_19[0][0]']
#
#  concatenate_19 (Concatenat  (None, 16, 16, 252)          0         ['concatenate_18[0][0]',
#  e)                                                                  'conv2d_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 252)          1008      ['concatenate_19[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 16, 16, 252)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 48)           12144     ['activation_20[0][0]']
#
#  concatenate_20 (Concatenat  (None, 16, 16, 300)          0         ['concatenate_19[0][0]',
#  e)                                                                  'conv2d_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 300)          1200      ['concatenate_20[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 300)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 48)           14448     ['activation_21[0][0]']
#
#  concatenate_21 (Concatenat  (None, 16, 16, 348)          0         ['concatenate_20[0][0]',
#  e)                                                                  'conv2d_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 348)          1392      ['concatenate_21[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 16, 16, 348)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 48)           16752     ['activation_22[0][0]']
#
#  concatenate_22 (Concatenat  (None, 16, 16, 396)          0         ['concatenate_21[0][0]',
#  e)                                                                  'conv2d_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 16, 16, 396)          1584      ['concatenate_22[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 16, 16, 396)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 16, 16, 48)           19056     ['activation_23[0][0]']
#
#  concatenate_23 (Concatenat  (None, 16, 16, 444)          0         ['concatenate_22[0][0]',
#  e)                                                                  'conv2d_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 16, 16, 444)          1776      ['concatenate_23[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 16, 16, 444)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 48)           21360     ['activation_24[0][0]']
#
#  concatenate_24 (Concatenat  (None, 16, 16, 492)          0         ['concatenate_23[0][0]',
#  e)                                                                  'conv2d_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 16, 16, 492)          1968      ['concatenate_24[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 16, 16, 492)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 48)           23664     ['activation_25[0][0]']
#
#  concatenate_25 (Concatenat  (None, 16, 16, 540)          0         ['concatenate_24[0][0]',
#  e)                                                                  'conv2d_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 16, 16, 540)          2160      ['concatenate_25[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 16, 16, 540)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 48)           25968     ['activation_26[0][0]']
#
#  concatenate_26 (Concatenat  (None, 16, 16, 588)          0         ['concatenate_25[0][0]',
#  e)                                                                  'conv2d_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 16, 16, 588)          2352      ['concatenate_26[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 16, 16, 588)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 48)           28272     ['activation_27[0][0]']
#
#  concatenate_27 (Concatenat  (None, 16, 16, 636)          0         ['concatenate_26[0][0]',
#  e)                                                                  'conv2d_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 636)          2544      ['concatenate_27[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 16, 16, 636)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 48)           30576     ['activation_28[0][0]']
#
#  concatenate_28 (Concatenat  (None, 16, 16, 684)          0         ['concatenate_27[0][0]',
#  e)                                                                  'conv2d_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 684)          2736      ['concatenate_28[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 16, 16, 684)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 48)           32880     ['activation_29[0][0]']
#
#  concatenate_29 (Concatenat  (None, 16, 16, 732)          0         ['concatenate_28[0][0]',
#  e)                                                                  'conv2d_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 732)          2928      ['concatenate_29[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 16, 16, 732)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 48)           35184     ['activation_30[0][0]']
#
#  concatenate_30 (Concatenat  (None, 16, 16, 780)          0         ['concatenate_29[0][0]',
#  e)                                                                  'conv2d_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 780)          3120      ['concatenate_30[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 16, 16, 780)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 48)           37488     ['activation_31[0][0]']
#
#  concatenate_31 (Concatenat  (None, 16, 16, 828)          0         ['concatenate_30[0][0]',
#  e)                                                                  'conv2d_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 828)          3312      ['concatenate_31[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 16, 16, 828)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 48)           39792     ['activation_32[0][0]']
#
#  concatenate_32 (Concatenat  (None, 16, 16, 876)          0         ['concatenate_31[0][0]',
#  e)                                                                  'conv2d_33[0][0]']
#
#  batch_normalization_34 (Ba  (None, 16, 16, 876)          3504      ['concatenate_32[0][0]']
#  tchNormalization)
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 150)          131550    ['batch_normalization_34[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 8, 8, 150)            0         ['conv2d_34[0][0]']
#  gePooling2D)
#
#  batch_normalization_35 (Ba  (None, 8, 8, 150)            600       ['average_pooling2d_1[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 8, 8, 150)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 48)             7248      ['activation_33[0][0]']
#
#  concatenate_33 (Concatenat  (None, 8, 8, 198)            0         ['average_pooling2d_1[0][0]',
#  e)                                                                  'conv2d_35[0][0]']
#
#  batch_normalization_36 (Ba  (None, 8, 8, 198)            792       ['concatenate_33[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 8, 8, 198)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 48)             9552      ['activation_34[0][0]']
#
#  concatenate_34 (Concatenat  (None, 8, 8, 246)            0         ['concatenate_33[0][0]',
#  e)                                                                  'conv2d_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 8, 8, 246)            984       ['concatenate_34[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 8, 8, 246)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 48)             11856     ['activation_35[0][0]']
#
#  concatenate_35 (Concatenat  (None, 8, 8, 294)            0         ['concatenate_34[0][0]',
#  e)                                                                  'conv2d_37[0][0]']
#
#  batch_normalization_38 (Ba  (None, 8, 8, 294)            1176      ['concatenate_35[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 8, 8, 294)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 48)             14160     ['activation_36[0][0]']
#
#  concatenate_36 (Concatenat  (None, 8, 8, 342)            0         ['concatenate_35[0][0]',
#  e)                                                                  'conv2d_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 8, 8, 342)            1368      ['concatenate_36[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 8, 8, 342)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 48)             16464     ['activation_37[0][0]']
#
#  concatenate_37 (Concatenat  (None, 8, 8, 390)            0         ['concatenate_36[0][0]',
#  e)                                                                  'conv2d_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 390)            1560      ['concatenate_37[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 8, 8, 390)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 8, 8, 48)             18768     ['activation_38[0][0]']
#
#  concatenate_38 (Concatenat  (None, 8, 8, 438)            0         ['concatenate_37[0][0]',
#  e)                                                                  'conv2d_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 438)            1752      ['concatenate_38[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 8, 8, 438)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 48)             21072     ['activation_39[0][0]']
#
#  concatenate_39 (Concatenat  (None, 8, 8, 486)            0         ['concatenate_38[0][0]',
#  e)                                                                  'conv2d_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 8, 8, 486)            1944      ['concatenate_39[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 486)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 48)             23376     ['activation_40[0][0]']
#
#  concatenate_40 (Concatenat  (None, 8, 8, 534)            0         ['concatenate_39[0][0]',
#  e)                                                                  'conv2d_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 8, 8, 534)            2136      ['concatenate_40[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 534)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 48)             25680     ['activation_41[0][0]']
#
#  concatenate_41 (Concatenat  (None, 8, 8, 582)            0         ['concatenate_40[0][0]',
#  e)                                                                  'conv2d_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 8, 8, 582)            2328      ['concatenate_41[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 8, 8, 582)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 48)             27984     ['activation_42[0][0]']
#
#  concatenate_42 (Concatenat  (None, 8, 8, 630)            0         ['concatenate_41[0][0]',
#  e)                                                                  'conv2d_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 8, 8, 630)            2520      ['concatenate_42[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 8, 8, 630)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 48)             30288     ['activation_43[0][0]']
#
#  concatenate_43 (Concatenat  (None, 8, 8, 678)            0         ['concatenate_42[0][0]',
#  e)                                                                  'conv2d_45[0][0]']
#
#  batch_normalization_46 (Ba  (None, 8, 8, 678)            2712      ['concatenate_43[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 8, 8, 678)            0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 48)             32592     ['activation_44[0][0]']
#
#  concatenate_44 (Concatenat  (None, 8, 8, 726)            0         ['concatenate_43[0][0]',
#  e)                                                                  'conv2d_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 8, 8, 726)            2904      ['concatenate_44[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 8, 8, 726)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 48)             34896     ['activation_45[0][0]']
#
#  concatenate_45 (Concatenat  (None, 8, 8, 774)            0         ['concatenate_44[0][0]',
#  e)                                                                  'conv2d_47[0][0]']
#
#  batch_normalization_48 (Ba  (None, 8, 8, 774)            3096      ['concatenate_45[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 8, 8, 774)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 8, 8, 48)             37200     ['activation_46[0][0]']
#
#  concatenate_46 (Concatenat  (None, 8, 8, 822)            0         ['concatenate_45[0][0]',
#  e)                                                                  'conv2d_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 8, 8, 822)            3288      ['concatenate_46[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 8, 8, 822)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 8, 8, 48)             39504     ['activation_47[0][0]']
#
#  concatenate_47 (Concatenat  (None, 8, 8, 870)            0         ['concatenate_46[0][0]',
#  e)                                                                  'conv2d_49[0][0]']
#
#  batch_normalization_50 (Ba  (None, 8, 8, 870)            3480      ['concatenate_47[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 8, 8, 870)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 8, 8, 48)             41808     ['activation_48[0][0]']
#
#  concatenate_48 (Concatenat  (None, 8, 8, 918)            0         ['concatenate_47[0][0]',
#  e)                                                                  'conv2d_50[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 918)            0         ['concatenate_48[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 918)                  0         ['average_pooling2d_2[0][0]']
#
#  dense (Dense)               (None, 10)                   9190      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1372060 (5.23 MB)
# Trainable params: 1325032 (5.05 MB)
# Non-trainable params: 47028 (183.70 KB)
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(),'saved_models')
model_name = 'cifar10_densenet_model.{epoch:02d}.h5'
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)
filepath = os.path.join(save_dir,model_name)

# %%
checkpoint = ModelCheckpoint(filepath=filepath, moniter='val_acc', verbose=1, save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5,min_lr=0.5e-6)

callbacks = [checkpoint,lr_reducer,lr_scheduler]

# %%
if not data_augmentation:
  print('Not using data augmentation.')
  model.fit(x_train,y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test,y_test), shuffle=True, callbacks=callbacks)
else:
    print('Using real-time augmentation.')
    datagen = ImageDataGenerator(
        featurewise_center=False, samplewise_center=False, featurewise_std_normalization=False, samplewise_std_normalization=False,
        zca_whitening=False, rotation_range =0, width_shift_range=0.1, height_shift_range=0.1,
        horizontal_flip=True, vertical_flip=False)

    datagen.fit(x_train)
    steps_per_epoch = math.ceil(len(x_train)/ batch_size)

    model.fit(x=datagen.flow(x_train,y_train,batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data = (x_test,y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time augmentation.
# Learning Rate:  0.001
# Epoch 1/8
# 782/782 [==============================] - ETA: 0s - loss: 1.9248 - acc: 0.3291
# Epoch 1: val_loss improved from inf to 1.74535, saving model to /content/saved_models/cifar10_densenet_model.01.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 782/782 [==============================] - 297s 322ms/step - loss: 1.9248 - acc: 0.3291 - val_loss: 1.7454 - val_acc: 0.3599 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 2/8
# 782/782 [==============================] - ETA: 0s - loss: 1.5232 - acc: 0.4512
# Epoch 2: val_loss did not improve from 1.74535
# 782/782 [==============================] - 254s 325ms/step - loss: 1.5232 - acc: 0.4512 - val_loss: 3.0293 - val_acc: 0.3202 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 3/8
# 782/782 [==============================] - ETA: 0s - loss: 1.3945 - acc: 0.4977
# Epoch 3: val_loss did not improve from 1.74535
# 782/782 [==============================] - 254s 325ms/step - loss: 1.3945 - acc: 0.4977 - val_loss: 2.2022 - val_acc: 0.4061 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 4/8
# 782/782 [==============================] - ETA: 0s - loss: 1.2956 - acc: 0.5339
# Epoch 4: val_loss improved from 1.74535 to 1.46731, saving model to /content/saved_models/cifar10_densenet_model.04.h5
# 782/782 [==============================] - 246s 315ms/step - loss: 1.2956 - acc: 0.5339 - val_loss: 1.4673 - val_acc: 0.4946 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 5/8
# 782/782 [==============================] - ETA: 0s - loss: 1.2150 - acc: 0.5651
# Epoch 5: val_loss did not improve from 1.46731
# 782/782 [==============================] - 254s 325ms/step - loss: 1.2150 - acc: 0.5651 - val_loss: 1.6727 - val_acc: 0.4558 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 6/8
# 782/782 [==============================] - ETA: 0s - loss: 1.1541 - acc: 0.5902
# Epoch 6: val_loss improved from 1.46731 to 1.31334, saving model to /content/saved_models/cifar10_densenet_model.06.h5
# 782/782 [==============================] - 255s 325ms/step - loss: 1.1541 - acc: 0.5902 - val_loss: 1.3133 - val_acc: 0.5463 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 7/8
# 782/782 [==============================] - ETA: 0s - loss: 1.1079 - acc: 0.6054
# Epoch 7: val_loss did not improve from 1.31334
# 782/782 [==============================] - 254s 325ms/step - loss: 1.1079 - acc: 0.6054 - val_loss: 1.9623 - val_acc: 0.4462 - lr: 0.0010
# Learning Rate:  0.001
# Epoch 8/8
# 782/782 [==============================] - ETA: 0s - loss: 1.0623 - acc: 0.6221
# Epoch 8: val_loss did not improve from 1.31334
# 782/782 [==============================] - 246s 315ms/step - loss: 1.0623 - acc: 0.6221 - val_loss: 1.4283 - val_acc: 0.5463 - lr: 0.0010

# %%
scores = model.evaluate(x_test,y_test,verbose=0)
print("Test loss: ", scores[0])
print("Test accuracy: ", scores[1])
# Out:
# Test loss:  1.4282664060592651
# Test accuracy:  0.5462999939918518

# %% [markdown]
# The Accuracy is low because of lower trainable(less epochs) data.
